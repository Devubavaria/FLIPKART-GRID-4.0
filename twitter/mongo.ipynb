# %%
# from tweepy import Stream
from tweepy import OAuthHandler
# from tweepy.streaming import StreamListener
from tweepy import API
from tweepy import Cursor
# import credentials
from ipynb.fs.full.credentials import *
import json
import requests
import os
from pymongo import MongoClient

client = MongoClient("mongodb+srv://devuubavaria:Devubavaria2002@cluster0.imppc.mongodb.net/?retryWrites=true&w=majority")
    #"mongodb+srv://Vasu:htccg321@cluster0-miow4.mongodb.net/flipkart-grid?retryWrites=true&w=majority"

database = client["flipkart-grid"]
collection = database["twitter_data"]


def authenticate():
    auth = OAuthHandler(api_key,api_key_secret)
    auth.set_access_token(access_token,access_token_secret)
    return auth


# import base64
# with open("yourfile.ext", "rb") as image_file:
#     encoded_string = base64.b64encode(image_file.read())


def twitter_client(num,handle):
    auth = authenticate()
    client_handler = API(auth)
    tweets = []
    for tweet in Cursor(client_handler.search_tweets,q=handle,lang="en").items(num):
        tweets.append(tweet)
    return tweets

#     for tweet in Cursor(client_handler.user_timeline, screen_name=twitter_user).items(num):
#         tweets.append(tweet)

    # for tweet in tweepy.Cursor(api.search,q="#unitedAIRLINES",count=100,
    #                            lang="en",
    


fashion_handles = ['FASHIONABLE', 'SHEIN_official', 'VogueParis', 'Refinery29','TimesFashion', 'AmazonFashionIn']

num = 200


# def download_image(pic_urls, handle, id):
#     if not os.path.exists("./data"):
#         os.mkdir("./data")
#     if not os.path.exists("./data/{0}".format(handle)):
#         os.mkdir("./data/{0}".format(handle))
#     for i, pic_url in enumerate(pic_urls):
#         img_data = requests.get(pic_url).content
#         with open('./data/{0}/{1}_{2}.jpg'.format(handle, id, i), 'wb') as handler:
#             handler.write(img_data)


extraction = {}
for handle in fashion_handles:
    # extraction[handle] = {}

    data = twitter_client(num, handle)
    k = 0
    for i, tweet in enumerate(data):
        obj = {}
        json_str = tweet._json
        # try:
        urls = []
        try:
            for twt in (json_str['extended_entities']['media']):
                urls.append(twt['media_url'])
        except:
            pass
        if not urls == []:
            #     download_image(urls, handle, json_str['id'])
            obj['id'] = json_str['id']
            obj['favorite_count'] = json_str['favorite_count']
            obj['text'] = json_str['text']
            obj['created_at'] = json_str['created_at']
            obj["media_urls"] = urls
            obj['source'] = handle
            # extraction[handle][k] = obj
            # k += 1
            collection.insert_one(obj)
        # except:
        #     pass
        print(handle, "tweet", i)
    print("Completed - ", handle)

with open("dump.json", 'w+') as file:
    json.dump(extraction, file)
    # file.write(json.dumps(extraction))
# Out:
# FASHIONABLE tweet 0
# FASHIONABLE tweet 1
# FASHIONABLE tweet 2
# FASHIONABLE tweet 3
# FASHIONABLE tweet 4
# FASHIONABLE tweet 5
# FASHIONABLE tweet 6
# FASHIONABLE tweet 7
# FASHIONABLE tweet 8
# FASHIONABLE tweet 9
# FASHIONABLE tweet 10
# FASHIONABLE tweet 11
# FASHIONABLE tweet 12
# FASHIONABLE tweet 13
# FASHIONABLE tweet 14
# FASHIONABLE tweet 15
# TimesFashion tweet 27
# TimesFashion tweet 28
# TimesFashion tweet 29
# TimesFashion tweet 30
# TimesFashion tweet 31
# TimesFashion tweet 32
# TimesFashion tweet 33
# TimesFashion tweet 34
# TimesFashion tweet 35
# TimesFashion tweet 36
# TimesFashion tweet 37
# TimesFashion tweet 38
# TimesFashion tweet 39
# TimesFashion tweet 40
# TimesFashion tweet 41
# TimesFashion tweet 42
# TimesFashion tweet 43
# TimesFashion tweet 44
# TimesFashion tweet 45
# TimesFashion tweet 46
# TimesFashion tweet 47
# TimesFashion tweet 48
# TimesFashion tweet 49
# TimesFashion tweet 50
# TimesFashion tweet 51
# TimesFashion tweet 52
# TimesFashion tweet 53
# TimesFashion tweet 54
# TimesFashion tweet 55
# Completed -  TimesFashion
# AmazonFashionIn tweet 0
# AmazonFashionIn tweet 1
# AmazonFashionIn tweet 2
# AmazonFashionIn tweet 3
# AmazonFashionIn tweet 4
# AmazonFashionIn tweet 5
# AmazonFashionIn tweet 6
# AmazonFashionIn tweet 7
# AmazonFashionIn tweet 8
# AmazonFashionIn tweet 9
# AmazonFashionIn tweet 10
# AmazonFashionIn tweet 11
# AmazonFashionIn tweet 12
# AmazonFashionIn tweet 13
# AmazonFashionIn tweet 14
# AmazonFashionIn tweet 15
# AmazonFashionIn tweet 16
# AmazonFashionIn tweet 17
# AmazonFashionIn tweet 18
# AmazonFashionIn tweet 19
# AmazonFashionIn tweet 20
# AmazonFashionIn tweet 21
# AmazonFashionIn tweet 22
# AmazonFashionIn tweet 23
# AmazonFashionIn tweet 24
# AmazonFashionIn tweet 25
# AmazonFashionIn tweet 26
# AmazonFashionIn tweet 27
# AmazonFashionIn tweet 28
# AmazonFashionIn tweet 29
# AmazonFashionIn tweet 30
# AmazonFashionIn tweet 31
# AmazonFashionIn tweet 32
# AmazonFashionIn tweet 33
# AmazonFashionIn tweet 34
# AmazonFashionIn tweet 35
# AmazonFashionIn tweet 36
# AmazonFashionIn tweet 37
# AmazonFashionIn tweet 38
# AmazonFashionIn tweet 39
# AmazonFashionIn tweet 40
# AmazonFashionIn tweet 41
# AmazonFashionIn tweet 42
# AmazonFashionIn tweet 43
# AmazonFashionIn tweet 44
# AmazonFashionIn tweet 45
# AmazonFashionIn tweet 46
# AmazonFashionIn tweet 47
# AmazonFashionIn tweet 48
# AmazonFashionIn tweet 49
# AmazonFashionIn tweet 50
# AmazonFashionIn tweet 51
# AmazonFashionIn tweet 52
# AmazonFashionIn tweet 53
# AmazonFashionIn tweet 54
# AmazonFashionIn tweet 55
# AmazonFashionIn tweet 56
# AmazonFashionIn tweet 57
# AmazonFashionIn tweet 58
# AmazonFashionIn tweet 59
# AmazonFashionIn tweet 60
# AmazonFashionIn tweet 61
# AmazonFashionIn tweet 62
# AmazonFashionIn tweet 63
# AmazonFashionIn tweet 64
# AmazonFashionIn tweet 65
# Completed -  AmazonFashionIn
